# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler,RobustScaler,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout,Bidirectional, LSTM, SimpleRNN,GRU,Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# Load the dataset
# df = pd.read_excel('../../dataset/Dataset_IoV.xlsx')  
df = pd.read_csv('..//..//dataset//preliminary_dataset.csv')  


# Separating features and target
X = df[['Number of Lanes', 'Status of driver', 'Nature of environment', 'Velocity of vehicle', 'Distance between vehicles', 'Breaking capability']]
y = df['Collussion']
# scaler=RobustScaler()
# X_scaled = scaler.fit_transform(X)

# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
X_scaled = X

# Reshape input to be 3D [samples, timesteps, features] for LSTM
X_scaled = np.reshape(X_scaled, (X_scaled.shape[0], 1, X_scaled.shape[1]))

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
print(X_train.shape, y_train.shape,X_scaled.shape)
# Out:
# (32000, 1, 6) (32000,) (40000, 1, 6)

# %% [markdown]
# # Model

# %%
def build_drnn():
    model = Sequential()
    
    # Input layer
    model.add(Input(shape=(X_train.shape[1], X_train.shape[2])))
    
    # DRNN layers with 3 hidden layers
    model.add(SimpleRNN(units=50, activation='relu', return_sequences=True))
    model.add(SimpleRNN(units=50, activation='relu', return_sequences=True))
    model.add(SimpleRNN(units=50, activation='relu'))
    
    # Output layer
    model.add(Dense(units=1, activation='sigmoid'))
    
    # Compile the model
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['mse', 'mae'])
    
    return model

# %%
model = build_drnn()
history = model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - loss: 0.1573 - mae: 0.1036 - mse: 0.0486 - val_loss: 0.0711 - val_mae: 0.0358 - val_mse: 0.0213
# Epoch 2/5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0684 - mae: 0.0386 - mse: 0.0206 - val_loss: 0.0597 - val_mae: 0.0364 - val_mse: 0.0184
# Epoch 3/5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0563 - mae: 0.0336 - mse: 0.0174 - val_loss: 0.0474 - val_mae: 0.0279 - val_mse: 0.0150
# Epoch 4/5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0506 - mae: 0.0311 - mse: 0.0157 - val_loss: 0.0435 - val_mae: 0.0274 - val_mse: 0.0137
# Epoch 5/5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0473 - mae: 0.0286 - mse: 0.0147 - val_loss: 0.0433 - val_mae: 0.0288 - val_mse: 0.0137

# %%
# Instantiate and train the model
model = build_drnn()
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 0.1563 - mae: 0.1044 - mse: 0.0495 - val_loss: 0.0773 - val_mae: 0.0465 - val_mse: 0.0239
# Epoch 2/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0609 - mae: 0.0370 - mse: 0.0187 - val_loss: 0.0495 - val_mae: 0.0318 - val_mse: 0.0152
# Epoch 3/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0498 - mae: 0.0303 - mse: 0.0154 - val_loss: 0.0438 - val_mae: 0.0289 - val_mse: 0.0137
# Epoch 4/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0507 - mae: 0.0308 - mse: 0.0158 - val_loss: 0.0516 - val_mae: 0.0279 - val_mse: 0.0155
# Epoch 5/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0431 - mae: 0.0267 - mse: 0.0135 - val_loss: 0.0438 - val_mae: 0.0250 - val_mse: 0.0135
# Epoch 6/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0429 - mae: 0.0263 - mse: 0.0136 - val_loss: 0.0401 - val_mae: 0.0264 - val_mse: 0.0128
# Epoch 7/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0414 - mae: 0.0255 - mse: 0.0131 - val_loss: 0.0465 - val_mae: 0.0272 - val_mse: 0.0145
# Epoch 8/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0424 - mae: 0.0265 - mse: 0.0136 - val_loss: 0.0390 - val_mae: 0.0253 - val_mse: 0.0127
# Epoch 9/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0420 - mae: 0.0261 - mse: 0.0137 - val_loss: 0.0378 - val_mae: 0.0240 - val_mse: 0.0123
# Epoch 10/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0389 - mae: 0.0244 - mse: 0.0125 - val_loss: 0.0462 - val_mae: 0.0283 - val_mse: 0.0149
# Epoch 11/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0380 - mae: 0.0240 - mse: 0.0122 - val_loss: 0.0390 - val_mae: 0.0258 - val_mse: 0.0128
# Epoch 12/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0393 - mae: 0.0245 - mse: 0.0125 - val_loss: 0.0406 - val_mae: 0.0263 - val_mse: 0.0129
# Epoch 13/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0375 - mae: 0.0238 - mse: 0.0120 - val_loss: 0.0381 - val_mae: 0.0235 - val_mse: 0.0125
# Epoch 14/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0384 - mae: 0.0237 - mse: 0.0122 - val_loss: 0.0515 - val_mae: 0.0267 - val_mse: 0.0164
# Epoch 15/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0414 - mae: 0.0255 - mse: 0.0130 - val_loss: 0.0376 - val_mae: 0.0251 - val_mse: 0.0124
# Epoch 16/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0371 - mae: 0.0232 - mse: 0.0117 - val_loss: 0.0439 - val_mae: 0.0240 - val_mse: 0.0138
# Epoch 17/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0380 - mae: 0.0237 - mse: 0.0122 - val_loss: 0.0392 - val_mae: 0.0238 - val_mse: 0.0127
# Epoch 18/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0382 - mae: 0.0242 - mse: 0.0123 - val_loss: 0.0419 - val_mae: 0.0241 - val_mse: 0.0136
# Epoch 19/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0372 - mae: 0.0235 - mse: 0.0118 - val_loss: 0.0408 - val_mae: 0.0252 - val_mse: 0.0134
# Epoch 20/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0361 - mae: 0.0232 - mse: 0.0116 - val_loss: 0.0380 - val_mae: 0.0231 - val_mse: 0.0126
# Epoch 21/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0371 - mae: 0.0240 - mse: 0.0122 - val_loss: 0.0364 - val_mae: 0.0233 - val_mse: 0.0120
# Epoch 22/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0354 - mae: 0.0229 - mse: 0.0115 - val_loss: 0.0370 - val_mae: 0.0249 - val_mse: 0.0121
# Epoch 23/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0351 - mae: 0.0227 - mse: 0.0113 - val_loss: 0.0401 - val_mae: 0.0254 - val_mse: 0.0133
# Epoch 24/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0354 - mae: 0.0226 - mse: 0.0116 - val_loss: 0.0356 - val_mae: 0.0231 - val_mse: 0.0118
# Epoch 25/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0344 - mae: 0.0222 - mse: 0.0112 - val_loss: 0.0356 - val_mae: 0.0239 - val_mse: 0.0119
# Epoch 26/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0339 - mae: 0.0220 - mse: 0.0111 - val_loss: 0.0350 - val_mae: 0.0230 - val_mse: 0.0117
# Epoch 27/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0365 - mae: 0.0237 - mse: 0.0121 - val_loss: 0.0357 - val_mae: 0.0237 - val_mse: 0.0119
# Epoch 28/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0345 - mae: 0.0223 - mse: 0.0113 - val_loss: 0.0355 - val_mae: 0.0238 - val_mse: 0.0120
# Epoch 29/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0354 - mae: 0.0231 - mse: 0.0116 - val_loss: 0.0345 - val_mae: 0.0227 - val_mse: 0.0116
# Epoch 30/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0363 - mae: 0.0236 - mse: 0.0119 - val_loss: 0.0341 - val_mae: 0.0219 - val_mse: 0.0114
# Epoch 31/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0335 - mae: 0.0217 - mse: 0.0109 - val_loss: 0.0374 - val_mae: 0.0233 - val_mse: 0.0124
# Epoch 32/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0344 - mae: 0.0225 - mse: 0.0114 - val_loss: 0.0375 - val_mae: 0.0214 - val_mse: 0.0124
# Epoch 33/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0336 - mae: 0.0220 - mse: 0.0111 - val_loss: 0.0395 - val_mae: 0.0251 - val_mse: 0.0131
# Epoch 34/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0318 - mae: 0.0206 - mse: 0.0104 - val_loss: 0.0347 - val_mae: 0.0219 - val_mse: 0.0116
# Epoch 35/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0342 - mae: 0.0224 - mse: 0.0113 - val_loss: 0.0346 - val_mae: 0.0227 - val_mse: 0.0116
# Epoch 36/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0343 - mae: 0.0222 - mse: 0.0112 - val_loss: 0.0342 - val_mae: 0.0224 - val_mse: 0.0116
# Epoch 37/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0344 - mae: 0.0226 - mse: 0.0114 - val_loss: 0.0386 - val_mae: 0.0243 - val_mse: 0.0129
# Epoch 38/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0314 - mae: 0.0210 - mse: 0.0104 - val_loss: 0.0363 - val_mae: 0.0242 - val_mse: 0.0120
# Epoch 39/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0332 - mae: 0.0216 - mse: 0.0108 - val_loss: 0.0346 - val_mae: 0.0241 - val_mse: 0.0115
# Epoch 40/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0343 - mae: 0.0224 - mse: 0.0112 - val_loss: 0.0354 - val_mae: 0.0233 - val_mse: 0.0118
# Epoch 41/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0342 - mae: 0.0224 - mse: 0.0112 - val_loss: 0.0362 - val_mae: 0.0220 - val_mse: 0.0118
# Epoch 42/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0336 - mae: 0.0221 - mse: 0.0112 - val_loss: 0.0352 - val_mae: 0.0227 - val_mse: 0.0116
# Epoch 43/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0329 - mae: 0.0214 - mse: 0.0108 - val_loss: 0.0332 - val_mae: 0.0220 - val_mse: 0.0111
# Epoch 44/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0342 - mae: 0.0224 - mse: 0.0113 - val_loss: 0.0347 - val_mae: 0.0227 - val_mse: 0.0117
# Epoch 45/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0332 - mae: 0.0214 - mse: 0.0108 - val_loss: 0.0345 - val_mae: 0.0227 - val_mse: 0.0116
# Epoch 46/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0341 - mae: 0.0226 - mse: 0.0114 - val_loss: 0.0380 - val_mae: 0.0232 - val_mse: 0.0125
# Epoch 47/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0323 - mae: 0.0208 - mse: 0.0105 - val_loss: 0.0354 - val_mae: 0.0251 - val_mse: 0.0119
# Epoch 48/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0310 - mae: 0.0206 - mse: 0.0101 - val_loss: 0.0351 - val_mae: 0.0247 - val_mse: 0.0115
# Epoch 49/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0347 - mae: 0.0231 - mse: 0.0115 - val_loss: 0.0412 - val_mae: 0.0252 - val_mse: 0.0134
# Epoch 50/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0336 - mae: 0.0222 - mse: 0.0111 - val_loss: 0.0341 - val_mae: 0.0239 - val_mse: 0.0115

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
# Make predictions
y_pred = model.predict(X_test)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %%
# Convert continuous output to binary (0 or 1) using a threshold

y_pred_binary = (y_pred > 0.5).astype(int)
y_pred_binary = y_pred_binary.flatten()

# Convert y_test to a NumPy array and flatten
y_test_flat = y_test.to_numpy().flatten()

y_pred_flat = y_pred.flatten()
mse = mean_squared_error(y_test_flat, y_pred_flat)
print(f'Mean Squared Error for y_pred_flat (MSE): {mse:.16f}')

# Calculate RMSE
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error (RMSE): {rmse:.16f}')
# Out:
# Mean Squared Error for y_pred_flat (MSE): 0.0115068452432752
# Root Mean Squared Error (RMSE): 0.1072699643109625

# %%
import matplotlib.pyplot as plt

# Visualizing the loss, MSE, and MAE
plt.figure(figsize=(15, 5))

# Loss plot
plt.subplot(1, 3, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# MSE plot
plt.subplot(1, 3, 2)
plt.plot(history.history['mse'], label='Train MSE')
plt.plot(history.history['val_mse'], label='Validation MSE')
plt.title('Mean Squared Error')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# MAE plot
plt.subplot(1, 3, 3)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('Mean Absolute Error')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
import time

# Start time
start_time = time.time()

# Make predictions
y_pred = model.predict(X_test)

# End time
end_time = time.time()

# Total AES time
total_time = end_time - start_time  

# AES per sample
aes_per_sample = (total_time / len(X_test)) * 1e6  # Convert to microseconds (µs)

print(f'Total AES Time: {total_time:.6f} seconds')
print(f'AES Time per Sample: {aes_per_sample:.2f} µs/sample')
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Total AES Time: 1.990527 seconds
# AES Time per Sample: 248.82 µs/sample
