# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf

# %%
# checking tf versioon
print(tf.__version__)
# Out:
# 2.10.1

# %%
df=pd.read_excel('..//dataset//Dataset_Iov.xlsx')

# %%
print(df.shape)
# Out:
# (206775, 7)

# %%
# slipting the dataset into 10% rows
df1=df.iloc[:int(0.1*len(df))]

# %%
# saving the dataset into a new file
df1.to_csv('..//dataset//Dataset_Iov_10.csv',index=False)

# %%
df_dataset_1=pd.read_csv('..//dataset//final_dataset.csv')
df_dataset_2=pd.read_excel('..//dataset//Dataset_IoV.xlsx')

# %%
print(df_dataset_1.shape, df_dataset_2.shape)  # Number of rows and columns
print(df_dataset_1.info(), df_dataset_2.info())  # Data types and non-null counts
print(df_dataset_1.head(), df_dataset_2.head())  # First few rows
# Out:
# (400000, 7) (206775, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400000 entries, 0 to 399999
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Number of Lanes            400000 non-null  int64
#  1   Status of driver           400000 non-null  int64
#  2   Nature of environment      400000 non-null  int64
#  3   Velocity of vehicle        400000 non-null  float64
#  4   Distance between vehicles  400000 non-null  float64
#  5   Breaking capability        400000 non-null  int64
#  6   Collussion                 400000 non-null  int64
# dtypes: float64(2), int64(5)
# memory usage: 21.4 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206775 entries, 0 to 206774
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
# ...

# %%
print(df_dataset_1.isnull().sum(), df_dataset_2.isnull().sum())  # Count of missing values
# Out:
# Number of Lanes              0
# Status of driver             0
# Nature of environment        0
# Velocity of vehicle          0
# Distance between vehicles    0
# Breaking capability          0
# Collussion                   0
# dtype: int64 Number of Lanes              0
# Status of driver             0
# Nature of environment        0
# Velocity of vehicle          0
# Distance between vehicles    0
# Breaking capability          0
# Collussion                   0
# dtype: int64

# %%
print(df_dataset_1.describe(), df_dataset_2.describe())  # Summary statistics
# Out:
#        Number of Lanes  Status of driver  Nature of environment  \
# count    400000.000000     400000.000000          400000.000000
# mean          1.812772          1.538660               1.510568
# std           0.390095          0.498504               0.499889
# min           1.000000          1.000000               1.000000
# 25%           2.000000          1.000000               1.000000
# 50%           2.000000          2.000000               2.000000
# 75%           2.000000          2.000000               2.000000
# max           2.000000          2.000000               2.000000
#
#        Velocity of vehicle  Distance between vehicles  Breaking capability  \
# count        400000.000000              400000.000000        400000.000000
# mean              0.427756                   0.210196             0.084070
# std               0.131628                   0.351160             0.277493
# min               0.350000                   0.000000             0.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(df_dataset_1.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix - Dataset 1")
plt.show()

plt.figure(figsize=(10,6))
sns.heatmap(df_dataset_2.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix - Dataset 2")
plt.show()

# %%
df_dataset_1.boxplot(figsize=(10,6))
plt.title("Boxplot - Dataset 1")
plt.show()

df_dataset_2.boxplot(figsize=(10,6))
plt.title("Boxplot - Dataset 2")
plt.show()

# %%
df_dataset_1.hist(figsize=(12,8), bins=30)
plt.suptitle("Feature Distribution - Dataset 1")
plt.show()

df_dataset_2.hist(figsize=(12,8), bins=30)
plt.suptitle("Feature Distribution - Dataset 2")
plt.show()
