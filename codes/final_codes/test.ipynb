# %%
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv('..//..//dataset//final_dataset.csv')  # Replace with your dataset path

y = df['Collussion']

# %%
collusion_counts = df['Collussion'].value_counts()

print(collusion_counts)
# Out:
# Collussion
# 1    200000
# 0    200000
# Name: count, dtype: int64

# %%
import matplotlib as plt
#plot bar for collusion_counts
collusion_counts.plot(kind='bar', title='Collusion Counts')

# Show the plot
# Out:
# <Axes: title={'center': 'Collusion Counts'}, xlabel='Collussion'>
